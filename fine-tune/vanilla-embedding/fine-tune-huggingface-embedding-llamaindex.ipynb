# %% [markdown]
# # Goal
#
# The goal of this tutorial is to demonstrate how to preprocess a small corpus of financial reports using LlamaIndex to prepare sentence-level nodes and generate synthetic question-answer (QA) pairs. These pairs can then be used to fine-tune an embedding model for improved semantic search and retrieval performance. Specifically, you’ll learn how to:
# 	•	Download and parse PDF documents into sentence-level “nodes”
# 	•	Generate synthetic QA pairs using an LLM (like GPT-3.5)
# 	•	Structure the output into a training-ready dataset for fine-tuning
#
# This forms the foundational step in building better question-answering systems using retrieval-augmented generation (RAG) or fine-tuning embeddings.

# %% [markdown]
# # 1. Download dataset

# %% [markdown]
# This code sets up a small document corpus with one training and one validation PDF, and processes each into sentence-level “nodes” using LlamaIndex utilities. These nodes can then be used for tasks like:
# - Embedding and similarity search
# - RAG (Retrieval-Augmented Generation)
# - Fine-tuning LLMs with sentence-level data

# %% [markdown]
# ## 1.1 Imports

# %% [markdown]
# - SimpleDirectoryReader: A LlamaIndex utility to load documents from a directory.
# - SentenceSplitter: Breaks documents into smaller chunks, typically sentence-level.

# %%
from llama_index.core import SimpleDirectoryReader
from llama_index.core.node_parser import SentenceSplitter

# %% [markdown]
# ## 1.2. Creating Directories and Downloading PDFs

# %% [markdown]
# - Creates train and val directories under data/10k/.
# - Downloads Uber 10-K (2021) and Lyft 10-K (2021) PDFs from LlamaIndex GitHub repo.
#      - uber_2021.pdf → val
#      - lyft_2021.pdf → train

# %%
# !mkdir -p 'data/10k/train'
# !mkdir -p 'data/10k/val'
# !wget 'https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/10k/uber_2021.pdf' -O 'data/10k/val/uber_2021.pdf'
# !wget 'https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/10k/lyft_2021.pdf' -O 'data/10k/train/lyft_2021.pdf'
# Out:
# --2025-04-10 23:40:28--  https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/10k/uber_2021.pdf
# 185.199.109.133, 185.199.110.133, 185.199.111.133, ...tent.com)...
# connected. to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443...
# HTTP request sent, awaiting response... 200 OK
# Length: 1880483 (1.8M) [application/octet-stream]
# Saving to: ‘data/10k/val/uber_2021.pdf’
#
# data/10k/val/uber_2 100%[===================>]   1.79M  3.28MB/s    in 0.5s
#
# 2025-04-10 23:40:29 (3.28 MB/s) - ‘data/10k/val/uber_2021.pdf’ saved [1880483/1880483]
#
# --2025-04-10 23:40:29--  https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/10k/lyft_2021.pdf
# 185.199.109.133, 185.199.110.133, 185.199.111.133, ...tent.com)...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1440303 (1.4M) [application/octet-stream]
# Saving to: ‘data/10k/train/lyft_2021.pdf’
#
# data/10k/train/lyft 100%[===================>]   1.37M  3.15MB/s    in 0.4s
#
# 2025-04-10 23:40:30 (3.15 MB/s) - ‘data/10k/train/lyft_2021.pdf’ saved [1440303/1440303]

# %%
TRAIN_DIR = "./data/10k/train"
VAL_DIR = "./data/10k/val"

# %% [markdown]
# ## 1.3. Define the load_corpus() function

# %% [markdown]
# 1.	Loads all .pdf documents from the given directory using SimpleDirectoryReader.
# 2.	Splits the documents into smaller units called nodes, typically one per sentence or paragraph, using SentenceSplitter.
# 3.	Returns the list of nodes.
#
# Optional verbose flag: If set to True, prints the number of documents and nodes processed.

# %%
def load_corpus(directory, verbose=False):

    reader = SimpleDirectoryReader(input_dir=directory,
    required_exts=[".pdf"],
    recursive=True)
    docs = reader.load_data()
    if verbose:
        print(f"Loaded {len(docs)} docs")

    parser = SentenceSplitter()
    nodes = parser.get_nodes_from_documents(docs, show_progress=verbose)

    if verbose:
        print(f"Parsed {len(nodes)} nodes")

    return nodes

# %% [markdown]
# ## 1.4. Create the training and validation nodes.

# %% [markdown]
# - Loads and parses lyft_2021.pdf into train_nodes (total 345 nodes)
# - Loads and parses uber_2021.pdf into val_nodes (total 407 nodes)

# %%
train_nodes = load_corpus(TRAIN_DIR, verbose=True)
val_nodes = load_corpus(VAL_DIR, verbose=True)
# Out:
# Loaded 238 docs
# Parsing nodes:   0%|          | 0/238 [00:00<?, ?it/s]
# Parsed 345 nodes
# Loaded 307 docs
# Parsing nodes:   0%|          | 0/307 [00:00<?, ?it/s]
# Parsed 407 nodes

# %% [markdown]
# ## 1.5. Display a sample Node

# %% [markdown]
# Following is an example of the first node from the training data

# %%
train_nodes[0].to_json()
# Out:
# '{"id_": "d72149af-72f4-4ffe-bcba-479381f4673a", "embedding": null, "metadata": {"page_label": "1", "file_name": "lyft_2021.pdf", "file_path": "/Users/tuhinsharma/Documents/Git/genai-playground/fine-tune/vanilla-embedding/data/10k/train/lyft_2021.pdf", "file_type": "application/pdf", "file_size": 1440303, "creation_date": "2025-04-10", "last_modified_date": "2025-04-10"}, "excluded_embed_metadata_keys": ["file_name", "file_type", "file_size", "creation_date", "last_modified_date", "last_accessed_date"], "excluded_llm_metadata_keys": ["file_name", "file_type", "file_size", "creation_date", "last_modified_date", "last_accessed_date"], "relationships": {"1": {"node_id": "abe43533-c71a-4081-b229-14f3301b057e", "node_type": "4", "metadata": {"page_label": "1", "file_name": "lyft_2021.pdf", "file_path": "/Users/tuhinsharma/Documents/Git/genai-playground/fine-tune/vanilla-embedding/data/10k/train/lyft_2021.pdf", "file_type": "application/pdf", "file_size": 1440303, "creation_date": "2025-04-10", "last_modified_date": "2025-04-10"}, "hash": "692f6a80faad6718403b37b3300e251572fc8dcb0011e141b908472dac1d6a45", "class_name": "RelatedNodeInfo"}}, "metadata_template": "{key}: {value}", "metadata_separator": "\\n", "text": "UNITED STATES\\nSECURITIES AND EXCHANGE COMMISSIONWashington, D.C. 20549 FORM 10-K (Mark One)\\u2612ANNUAL REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934For the fiscal year ended December 31, 2021 OR \\u2610TRANSITION REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934 FOR THE TRANSITION PERIODFROM                      TOCommission File Number 001-38846 Lyft, Inc.(Exact name of Registrant as specified in its Charter)Delaware20-8809830 (State or other jurisdiction ofincorporation or organization)(I.R.S. Employer Identification No.)185 Berry Street, Suite 5000San Francisco, California94107 (Address of principal executive offices)(Zip Code) Registrant\\u2019s telephone number, including area code: (844) 250-2773Securities registered pursuant to Section 12(b) of the Act: Title of each class Trading Symbol(s)Name of each exchange on which registered Class A common stock, par value of $0.00001 per shareLYFT Nasdaq Global Select Market Securities registered pursuant to Section 12(g) of the Act: None Indicate by check mark if the Registrant is a well-known seasoned issuer, as defined in Rule 405 of the Securities Act. Yes \\u2612 \\u00a0No \\u2610Indicate by check mark if the Registrant is not required to file reports pursuant to Section 13 or 15(d) of the Act.  Yes \\u2610 \\u00a0No \\u2612Indicate by check mark whether the Registrant: (1) has filed all reports required to be filed by Section 13 or 15(d) of the Securities Exchange Act of 1934 during the preceding 12 months (or for suchshorter period that the Registrant was required to file such reports), and (2) has been subject to such filing requirements for the past 90 days.  Yes \\u2612 \\u00a0No \\u2610Indicate by check mark whether the Registrant has submitted electronically every Interactive Data File required to be submitted pursuant to Rule 405 of Regulation S-T (\\u00a7232.405 of this chapter) duringthe preceding 12 months (or for such shorter period that the Registrant was required to submit such files).  Yes \\u2612 \\u00a0No \\u2610Indicate by check mark whether the registrant is a large accelerated filer, an accelerated filer, a non-accelerated filer, smaller reporting company, or an emerging growth company. See the definitions of\\u201clarge accelerated filer,\\u201d \\u201caccelerated filer,\\u201d \\u201csmaller reporting company,\\u201d and \\u201cemerging growth company\\u201d in Rule 12b-2 of the Exchange Act.Large accelerated filer\\u2612 Accelerated filer \\u2610 Non-accelerated filer\\u2610 Smaller reporting company \\u2610 Emerging growth company\\u2610 If an emerging growth company, indicate by check mark if the registrant has elected not to use the extended transition period for complying with any ...

# %% [markdown]
# # 2. Generate synthetic queries and prepare training dataset

# %% [markdown]
# This code is typically used as a preprocessing step in embedding model fine-tuning—where you’re training a vector embedding model to better understand and encode semantic relationships between questions and their corresponding answers. This code snippet is part of a workflow using LlamaIndex to prepare a dataset for fine-tuning an embedding model for a question-answering (QA) task. Here’s a breakdown of what each part of the code does:

# %% [markdown]
# ## 2.1. Imports

# %% [markdown]
# - generate_qa_embedding_pairs: Generates QA pairs from a set of documents (called nodes) using an LLM and stores them in a format useful for fine-tuning an embedding model.
# - EmbeddingQAFinetuneDataset: Utility class to load the generated QA pair dataset.
# - OpenAI: Wrapper around OpenAI models (like GPT-3.5) for use in LlamaIndex.

# %%
from llama_index.finetuning import generate_qa_embedding_pairs
from llama_index.core.evaluation import EmbeddingQAFinetuneDataset

# %% [markdown]
# ## 2.2. Generate QA Pairs for Training and Validation

# %% [markdown]
# - Takes train_nodes and val_nodes (documents or chunks of text) as input.
# - Uses GPT-3.5 to generate question-answer pairs from each node.
# - Saves the output to "train_dataset.json" and "val_dataset.json".

# %% [markdown]
# You can choose to comment out the following block as it will require you to have openai credit and it shall take about 15 mins of time. `train_dataset.json` and `val_dataset.json` are already pushed to the code repository to save you the effort.

# %%
# from llama_index.llms.openai import OpenAI


# train_dataset = generate_qa_embedding_pairs(
#     llm=OpenAI(model="gpt-3.5-turbo"),
#     nodes=train_nodes,
#     output_path="train_dataset.json",
# )
# val_dataset = generate_qa_embedding_pairs(
#     llm=OpenAI(model="gpt-3.5-turbo"),
#     nodes=val_nodes,
#     output_path="val_dataset.json",
# )

# %% [markdown]
# ## 2.3. Load the Datasets

# %% [markdown]
# Loads the generated JSON files and returns structured objects that can be used later for fine-tuning the embedding model.

# %%
train_dataset = EmbeddingQAFinetuneDataset.from_json("train_dataset.json")
val_dataset = EmbeddingQAFinetuneDataset.from_json("val_dataset.json")

# %% [markdown]
# ## 2.4 Display a sample training record

# %% [markdown]
# Following is an example of the first node from the training data. 3 components from the dataset:
#  - corpus: Dictionary of documents
#  - queries: Dictionary of search queries
#  - relevant_docs: Mapping of which documents are relevant to which queries

# %%
print(next(iter(train_dataset.queries.items())))
print(next(iter(train_dataset.relevant_docs.items())))
print(next(iter(train_dataset.corpus.items())))
# Out:
# ('e5c751eb-26ca-4f05-b92f-6a701e59f631', "What is the market value of Lyft, Inc.'s common stock held by non-affiliates as of June 30, 2021, and how was this value determined?")
# ('e5c751eb-26ca-4f05-b92f-6a701e59f631', ['07e36631-d1de-4dc7-b055-927731dc8c18'])
# ('07e36631-d1de-4dc7-b055-927731dc8c18', 'UNITED STATES\nSECURITIES AND EXCHANGE COMMISSIONWashington, D.C. 20549 FORM 10-K (Mark One)☒ANNUAL REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934For the fiscal year ended December 31, 2021 OR ☐TRANSITION REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934 FOR THE TRANSITION PERIODFROM                      TOCommission File Number 001-38846 Lyft, Inc.(Exact name of Registrant as specified in its Charter)Delaware20-8809830 (State or other jurisdiction ofincorporation or organization)(I.R.S. Employer Identification No.)185 Berry Street, Suite 5000San Francisco, California94107 (Address of principal executive offices)(Zip Code) Registrant’s telephone number, including area code: (844) 250-2773Securities registered pursuant to Section 12(b) of the Act: Title of each class Trading Symbol(s)Name of each exchange on which registered Class A common stock, par value of $0.00001 per shareLYFT Nasdaq Global Select Market Securities registered pursuant to Section 12(g) of the Act: None Indicate by check mark if the Registrant is a well-known seasoned issuer, as defined in Rule 405 of the Securities Act. Yes ☒ \xa0No ☐Indicate by check mark if the Registrant is not required to file reports pursuant to Section 13 or 15(d) of the Act.  Yes ☐ \xa0No ☒Indicate by check mark whether the Registrant: (1) has filed all reports required to be filed by Section 13 or 15(d) of the Securities Exchange Act of 1934 during the preceding 12 months (or for suchshorter period that the Registrant was required to file such reports), and (2) has been subject to such filing requirements for the past 90 days.  Yes ☒ \xa0No ☐Indicate by check mark whether the Registrant has submitted electronically every Interactive Data File required to be submitted pursuant to Rule 405 of Regulation S-T (§232.405 of this chapter) duringthe preceding 12 months (or for such shorter period that the Registrant was required to submit such files).  Yes ☒ \xa0No ☐Indicate by check mark whether the registrant is a large accelerated filer, an accelerated filer, a non-accelerated filer, smaller reporting company, or an emerging growth company. See the definitions of“large accelerated filer,” “accelerated filer,” “smaller reporting company,” and “emerging growth company” in Rule 12b-2 of the Exchange Act.Large accelerated filer☒ Accelerated filer ☐ Non-accelerated filer☐ Smaller reporting company ☐ Emerging growth company☐ If an emerging growth company, indicate by check mark if the registrant has elected not to use the extended transition period for complying with any new or revised financial accounting standardsprovided pursuant to Section 13(a) of the Exchange Act.  ☐ Indicate by check mark whether the registrant has filed a report on and attestation to its management’s assessment of the effectiveness of its internal control over financial reporting under Section 404(b)of the Sarbanes-Oxley Act (15 U.S.C. 7262(b)) by the registered public accounting firm that prepared or issued its audit report. ☒ Indicate by check mark whether the Registrant is a shell company (as defined in Rule 12b-2 of the Exchange Act).  Yes ☐ \xa0No ☒The aggregate market value of the Registrant’s common stock held by non-affiliates of the Registrant on June 30, 2021, the last business day of its most recently completed second fiscal quarter, was$19.6 billion based on the closing sales price of the Registrant’s Class A common stock on that date.On February 22, 2022, the Registrant had 339,954,714 shares of Class A common stock and 8,602,629 shares of Class B common stock outstanding.DOCUMENTS INCORPORATED BY REFERENCE Portions of the registrant’s Proxy Statement for the 2022 Annual Meeting of Stockholders are incorporated herein by reference in Part III of this Annual Report on Form 10-K to the extent stated herein.Such proxy statement will be filed with the Securities and Exchange Commission within 120 days of the re ...

# %% [markdown]
# # 3. Evaluation metrics

# %% [markdown]
# ## 3.1 Imports

# %% [markdown]
# - Imports an evaluator that tests how well a model retrieves relevant documents for given queries.
# - Imports the model class to load a pre-trained SentenceTransformer.
# - Used to create output directories if they don’t already exist.

# %%
from sentence_transformers.evaluation import InformationRetrievalEvaluator
from sentence_transformers import SentenceTransformer
from pathlib import Path
# Out:
# INFO:datasets:PyTorch version 2.6.0 available.
# PyTorch version 2.6.0 available.

# %% [markdown]
# ## 3.2 Function: evaluate_st

# %% [markdown]
# This function takes:
# - dataset: An object that must contain .corpus, .queries, and .relevant_docs.
# - model_id: The model name or path to load from SentenceTransformer.
# - name: A name identifier for the evaluation report.Extracts the required components from the dataset:

# %%
def evaluate_st(
    dataset,
    model_id,
    name,
):  
    corpus = dataset.corpus
    queries = dataset.queries
    relevant_docs = dataset.relevant_docs

    evaluator = InformationRetrievalEvaluator(
        queries, corpus, relevant_docs, name=name
    )
    model = SentenceTransformer(model_id)
    output_path = "results/"
    Path(output_path).mkdir(exist_ok=True, parents=True)
    return evaluator(model, output_path=output_path)

# %% [markdown]
# # 4. Finetune a public huggingface embedding model using SentenceTransformers

# %% [markdown]
# ## 4.1 Define the model id (Hugging Face model id)

# %% [markdown]
# We shall fine-tune the opensource model `mixedbread-ai/mxbai-embed-xsmall-v1`

# %%
model_id = "mixedbread-ai/mxbai-embed-xsmall-v1"
finetuned_model_id = "fine-tuned-mxbai-embed-xsmall-v1"

# %% [markdown]
# ## 4.2 Start the Fine-tuning process

# %% [markdown]
# The code fine-tunes a pre-trained Sentence Transformer model (e.g., one that converts sentences into embeddings) using your own training and validation datasets, saving the updated model to a specified location after 5 training epochs.
#
# Here’s what each argument means:
#  - train_dataset: The training data - triplet data.
#  - model_id: The base model to fine-tune (e.g., "sentence-transformers/all-MiniLM-L6-v2").
#  - model_output_path: Where to save the fine-tuned model after training (finetuned_model_id is a variable holding that path).
#  - val_dataset: The validation dataset used to monitor performance during training.
#  - epochs=5: The number of passes over the training data.
#  - use_all_docs=True: If set to True, it may use all documents in the dataset rather than filtering or sampling.

# %%
from llama_index.finetuning import SentenceTransformersFinetuneEngine
finetune_engine = SentenceTransformersFinetuneEngine(
    train_dataset,
    model_id=model_id,
    model_output_path=finetuned_model_id,
    val_dataset=val_dataset,
    epochs=5,
    use_all_docs=True
)
finetune_engine.finetune()
# Out:
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: mps
# Use pytorch device_name: mps
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: mixedbread-ai/mxbai-embed-xsmall-v1
# Load pretrained SentenceTransformer: mixedbread-ai/mxbai-embed-xsmall-v1
# Computing widget examples:   0%|          | 0/1 [00:00<?, ?example/s]
#     <div>
#
#       <progress value='345' max='345' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [345/345 01:22, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Cosine Accuracy@1</th>
#       <th>Cosine Accuracy@3</th>
#       <th>Cosine Accuracy@5</th>
#       <th>Cosine Accuracy@10</th>
#       <th>Cosine Precision@1</th>
#       <th>Cosine Precision@3</th>
#       <th>Cosine Precision@5</th>
#       <th>Cosine Precision@10</th>
#       <th>Cosine Recall@1</th>
#       <th>Cosine Recall@3</th>
#       <th>Cosine Recall@5</th>
#       <th>Cosine Recall@10</th>
#       <th>Cosine Ndcg@10</th>
#       <th>Cosine Mrr@10</th>
#       <th>Cosine Map@100</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.538084</td>
#       <td>0.771499</td>
#       <td>0.837838</td>
#       <td>0.895577</td>
#       <td>0.538084</td>
#       <td>0.257166</td>
#       <td>0.167568</td>
#       <td>0.089558</td>
#       <td>0.538084</td>
#       <td>0.771499</td>
#       <td>0.837838</td>
#       <td>0.895577</td>
#       <td>0.722603</td>
#       <td>0.666528</td>
#       <td>0.670044</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.545455</td>
#       <td>0.762899</td>
#       <td>0.829238</td>
#       <td>0.893120</td>
#       <td>0.545455</td>
#       <td>0.254300</td>
#       <td>0.165848</td>
#       <td>0.089312</td>
#       <td>0.545455</td>
#       <td>0.762899</td>
#       <td>0.829238</td>
#       <td>0.893120</td>
#       <td>0.724460</td>
#       <td>0.669787</td>
#       <td>0.673680</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.560197</td>
#       <td>0.775184</td>
#       <td>0.831695</td>
#       <td>0.896806</td>
#       <td>0.560197</td>
#       <td>0.258395</td>
#       <td>0.166339</td>
#       <td>0.089681</td>
#       <td>0.560197</td>
#       <td>0.775184</td>
#       <td>0.831695</td>
#       <td>0.896806</td>
#       <td>0.733493</td>
#       <td>0.680677</td>
#       <td>0.684266</td>
#     </tr>
#     <tr>
#       <td>138</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.565111</td>
#       <td>0.770270</td>
#       <td>0.834152</td>
#       <td>0.894349</td>
#       <td>0.565111</td>
#       <td>0.256757</td>
#       <td>0.166830</td>
#       <td>0.089435</td>
#       <td>0.565111</td>
#       <td>0.770270</td>
#       <td>0.834152</td>
#       <td>0.894349</td>
#       <td>0.733484</td>
#       <td>0.681553</td>
#       <td>0.685234</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.566339</td>
#       <td>0.770270</td>
#       <td>0.834152</td>
#       <td>0.891892</td>
#       <td>0.566339</td>
#       <td>0.256757</td>
#       <td>0.166830</td>
#       <td>0.089189</td>
#       <td>0.566339</td>
#       <td>0.770270</td>
#       <td>0.834152</td>
#       <td>0.891892</td>
#       <td>0.734249</td>
#       <td>0.683176</td>
#       <td>0.687195</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.566339</td>
#       <td>0.780098</td>
#       <td>0.842752</td>
#       <td>0.896806</td>
#       <td>0.566339</td>
#       <td>0.260033</td>
#       <td>0.168550</td>
#       <td>0.089681</td>
#       <td>0.566339</td>
#       <td>0.780098</td>
#       <td>0.842752</td>
#       <td>0.896806</td>
#       <td>0.737364</td>
#       <td>0.685708</td>
#       <td>0.689692</td>
#     </tr>
#     <tr>
#       <td>207</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.566339</td>
#       <td>0.778870</td>
#       <td>0.840295</td>
#       <td>0.899263</td>
#       <td>0.566339</td>
#       <td>0.259623</td>
#       <td>0.168059</td>
#       <td>0.089926</td>
#       <td>0.566339</td>
#       <td>0.778870</td>
#       <td>0.840295</td>
#       <td>0.899263</td>
#       <td>0.738089</td>
#       <td>0.685955</td>
#       <td>0.689694</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.572482</td>
#       <td>0.782555</td>
#       <td>0.842752</td>
#       <td>0.895577</td>
#       <td>0.572482</td>
#       <td>0.260852</td>
#       <td>0.168550</td>
#       <td>0.089558</td>
#       <td>0.572482</td>
#       <td>0.782555</td>
#       <td>0.842752</td>
#       <td>0.895577</td>
#       <td>0.738781</td>
#       <td>0.688057</td>
#       <td>0.692054</td>
#     </tr>
#     <tr>
#       <td>276</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.568796</td>
#       <td>0.783784</td>
#       <td>0.841523</td>
#       <td>0.893120</td>
#       <td>0.568796</td>
#       <td>0.261261</td>
#       <td>0.168305</td>
#       <td>0.089312</td>
#       <td>0.568796</td>
#       <td>0.783784</td>
#       <td>0.841523</td>
#       <td>0.893120</td>
#       <td>0.736463</td>
#       <td>0.685608</td>
#       <td>0.689784</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.571253</td>
#       <td>0.786241</td>
#       <td>0.841523</td>
#       <td>0.893120</td>
#       <td>0.571253</td>
#       <td>0.262080</td>
#       <td>0.168305</td>
#       <td>0.089312</td>
#       <td>0.571253</td>
#       <td>0.786241</td>
#       <td>0.841523</td>
#       <td>0.893120</td>
#       <td>0.737726</td>
#       <td>0.687265</td>
#       <td>0.691447</td>
#     </tr>
#     <tr>
#       <td>345</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.570025</td>
#       <td>0.783784</td>
#       <td>0.841523</td>
#       <td>0.895577</td>
#       <td>0.570025</td>
#       <td>0.261261</td>
#       <td>0.168305</td>
#       <td>0.089558</td>
#       <td>0.570025</td>
#       <td>0.783784</td>
#       <td>0.841523</td>
#       <td>0.895577</td>
#       <td>0.738527</td>
#       <td>0.687586</td>
#       <td>0.691527</td>
#     </tr>
#   </tbody>
# </table><p>
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 0.7246376811594203 after 50 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 0.7246376811594203 after 50 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 814
# Queries: 814
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 407
#
# Corpus: 407
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cosine
# Score-Function: cosine
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 53.81%
# Accuracy@1: 53.81%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 77.15%
# Accuracy@3: 77.15%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 83.78%
# Accuracy@5: 83.78%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 89.56%
# Accuracy@10: 89.56%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 53.81%
# Precision@1: 53.81%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 25.72%
# Precision@3: 25.72%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 16.76%
# Precision@5: 16.76%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 8.96%
# Precision@10: 8.96%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 53.81%
# Recall@1: 53.81%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 77.15%
# Recall@3: 77.15%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 83.78%
# Recall@5: 83.78%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 89.56%
# Recall@10: 89.56%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.6665
# MRR@10: 0.6665
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.7226
# NDCG@10: 0.7226
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.6700
# MAP@100: 0.6700
# INFO:sentence_transformers.SentenceTransformer:Save model to fine-tuned-mxbai-embed-xsmall-v1
# Save model to fine-tuned-mxbai-embed-xsmall-v1
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 1.0 after 69 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 1.0 after 69 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 814
# Queries: 814
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 407
#
# Corpus: 407
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cosine
# Score-Function: cosine
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 54.55%
# Accuracy@1: 54.55%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 76.29%
# Accuracy@3: 76.29%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 82.92%
# Accuracy@5: 82.92%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 89.31%
# Accuracy@10: 89.31%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 54.55%
# Precision@1: 54.55%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 25.43%
# Precision@3: 25.43%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 16.58%
# Precision@5: 16.58%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 8.93%
# Precision@10: 8.93%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 54.55%
# Recall@1: 54.55%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 76.29%
# Recall@3: 76.29%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 82.92%
# Recall@5: 82.92%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 89.31%
# Recall@10: 89.31%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.6698
# MRR@10: 0.6698
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.7245
# NDCG@10: 0.7245
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.6737
# MAP@100: 0.6737
# INFO:sentence_transformers.SentenceTransformer:Save model to fine-tuned-mxbai-embed-xsmall-v1
# Save model to fine-tuned-mxbai-embed-xsmall-v1
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 1.4492753623188406 after 100 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 1.4492753623188406 after 100 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 814
# Queries: 814
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 407
#
# Corpus: 407
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cosine
# Score-Function: cosine
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 56.02%
# Accuracy@1: 56.02%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 77.52%
# Accuracy@3: 77.52%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 83.17%
# Accuracy@5: 83.17%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 89.68%
# Accuracy@10: 89.68%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 56.02%
# Precision@1: 56.02%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 25.84%
# Precision@3: 25.84%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 16.63%
# Precision@5: 16.63%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 8.97%
# Precision@10: 8.97%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 56.02%
# Recall@1: 56.02%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 77.52%
# Recall@3: 77.52%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 83.17%
# Recall@5: 83.17%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 89.68%
# Recall@10: 89.68%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.6807
# MRR@10: 0.6807
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.7335
# NDCG@10: 0.7335
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.6843
# MAP@100: 0.6843
# INFO:sentence_transformers.SentenceTransformer:Save model to fine-tuned-mxbai-embed-xsmall-v1
# Save model to fine-tuned-mxbai-embed-xsmall-v1
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 2.0 after 138 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 2.0 after 138 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 814
# Queries: 814
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 407
#
# Corpus: 407
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cosine
# Score-Function: cosine
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 56.51%
# Accuracy@1: 56.51%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 77.03%
# Accuracy@3: 77.03%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 83.42%
# Accuracy@5: 83.42%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 89.43%
# Accuracy@10: 89.43%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 56.51%
# Precision@1: 56.51%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 25.68%
# Precision@3: 25.68%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 16.68%
# Precision@5: 16.68%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 8.94%
# Precision@10: 8.94%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 56.51%
# Recall@1: 56.51%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 77.03%
# Recall@3: 77.03%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 83.42%
# Recall@5: 83.42%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 89.43%
# Recall@10: 89.43%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.6816
# MRR@10: 0.6816
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.7335
# NDCG@10: 0.7335
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.6852
# MAP@100: 0.6852
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 2.1739130434782608 after 150 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 2.1739130434782608 after 150 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 814
# Queries: 814
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 407
#
# Corpus: 407
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cosine
# Score-Function: cosine
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 56.63%
# Accuracy@1: 56.63%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 77.03%
# Accuracy@3: 77.03%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 83.42%
# Accuracy@5: 83.42%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 89.19%
# Accuracy@10: 89.19%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 56.63%
# Precision@1: 56.63%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 25.68%
# Precision@3: 25.68%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 16.68%
# Precision@5: 16.68%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 8.92%
# Precision@10: 8.92%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 56.63%
# Recall@1: 56.63%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 77.03%
# Recall@3: 77.03%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 83.42%
# Recall@5: 83.42%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 89.19%
# Recall@10: 89.19%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.6832
# MRR@10: 0.6832
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.7342
# NDCG@10: 0.7342
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.6872
# MAP@100: 0.6872
# INFO:sentence_transformers.SentenceTransformer:Save model to fine-tuned-mxbai-embed-xsmall-v1
# Save model to fine-tuned-mxbai-embed-xsmall-v1
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 2.898550724637681 after 200 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 2.898550724637681 after 200 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 814
# Queries: 814
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 407
#
# Corpus: 407
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cosine
# Score-Function: cosine
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 56.63%
# Accuracy@1: 56.63%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 78.01%
# Accuracy@3: 78.01%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 84.28%
# Accuracy@5: 84.28%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 89.68%
# Accuracy@10: 89.68%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 56.63%
# Precision@1: 56.63%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 26.00%
# Precision@3: 26.00%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 16.86%
# Precision@5: 16.86%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 8.97%
# Precision@10: 8.97%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 56.63%
# Recall@1: 56.63%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 78.01%
# Recall@3: 78.01%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 84.28%
# Recall@5: 84.28%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 89.68%
# Recall@10: 89.68%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.6857
# MRR@10: 0.6857
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.7374
# NDCG@10: 0.7374
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.6897
# MAP@100: 0.6897
# INFO:sentence_transformers.SentenceTransformer:Save model to fine-tuned-mxbai-embed-xsmall-v1
# Save model to fine-tuned-mxbai-embed-xsmall-v1
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 3.0 after 207 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 3.0 after 207 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 814
# Queries: 814
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 407
#
# Corpus: 407
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cosine
# Score-Function: cosine
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 56.63%
# Accuracy@1: 56.63%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 77.89%
# Accuracy@3: 77.89%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 84.03%
# Accuracy@5: 84.03%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 89.93%
# Accuracy@10: 89.93%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 56.63%
# Precision@1: 56.63%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 25.96%
# Precision@3: 25.96%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 16.81%
# Precision@5: 16.81%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 8.99%
# Precision@10: 8.99%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 56.63%
# Recall@1: 56.63%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 77.89%
# Recall@3: 77.89%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 84.03%
# Recall@5: 84.03%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 89.93%
# Recall@10: 89.93%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.6860
# MRR@10: 0.6860
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.7381
# NDCG@10: 0.7381
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.6897
# MAP@100: 0.6897
# INFO:sentence_transformers.SentenceTransformer:Save model to fine-tuned-mxbai-embed-xsmall-v1
# Save model to fine-tuned-mxbai-embed-xsmall-v1
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 3.6231884057971016 after 250 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 3.6231884057971016 after 250 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 814
# Queries: 814
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 407
#
# Corpus: 407
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cosine
# Score-Function: cosine
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 57.25%
# Accuracy@1: 57.25%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 78.26%
# Accuracy@3: 78.26%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 84.28%
# Accuracy@5: 84.28%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 89.56%
# Accuracy@10: 89.56%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 57.25%
# Precision@1: 57.25%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 26.09%
# Precision@3: 26.09%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 16.86%
# Precision@5: 16.86%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 8.96%
# Precision@10: 8.96%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 57.25%
# Recall@1: 57.25%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 78.26%
# Recall@3: 78.26%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 84.28%
# Recall@5: 84.28%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 89.56%
# Recall@10: 89.56%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.6881
# MRR@10: 0.6881
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.7388
# NDCG@10: 0.7388
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.6921
# MAP@100: 0.6921
# INFO:sentence_transformers.SentenceTransformer:Save model to fine-tuned-mxbai-embed-xsmall-v1
# Save model to fine-tuned-mxbai-embed-xsmall-v1
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 4.0 after 276 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 4.0 after 276 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 814
# Queries: 814
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 407
#
# Corpus: 407
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cosine
# Score-Function: cosine
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 56.88%
# Accuracy@1: 56.88%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 78.38%
# Accuracy@3: 78.38%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 84.15%
# Accuracy@5: 84.15%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 89.31%
# Accuracy@10: 89.31%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 56.88%
# Precision@1: 56.88%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 26.13%
# Precision@3: 26.13%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 16.83%
# Precision@5: 16.83%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 8.93%
# Precision@10: 8.93%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 56.88%
# Recall@1: 56.88%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 78.38%
# Recall@3: 78.38%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 84.15%
# Recall@5: 84.15%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 89.31%
# Recall@10: 89.31%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.6856
# MRR@10: 0.6856
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.7365
# NDCG@10: 0.7365
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.6898
# MAP@100: 0.6898
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 4.3478260869565215 after 300 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 4.3478260869565215 after 300 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 814
# Queries: 814
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 407
#
# Corpus: 407
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cosine
# Score-Function: cosine
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 57.13%
# Accuracy@1: 57.13%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 78.62%
# Accuracy@3: 78.62%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 84.15%
# Accuracy@5: 84.15%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 89.31%
# Accuracy@10: 89.31%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 57.13%
# Precision@1: 57.13%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 26.21%
# Precision@3: 26.21%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 16.83%
# Precision@5: 16.83%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 8.93%
# Precision@10: 8.93%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 57.13%
# Recall@1: 57.13%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 78.62%
# Recall@3: 78.62%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 84.15%
# Recall@5: 84.15%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 89.31%
# Recall@10: 89.31%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.6873
# MRR@10: 0.6873
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.7377
# NDCG@10: 0.7377
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.6914
# MAP@100: 0.6914
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 5.0 after 345 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 5.0 after 345 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 814
# Queries: 814
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 407
#
# Corpus: 407
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cosine
# Score-Function: cosine
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 57.00%
# Accuracy@1: 57.00%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 78.38%
# Accuracy@3: 78.38%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 84.15%
# Accuracy@5: 84.15%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 89.56%
# Accuracy@10: 89.56%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 57.00%
# Precision@1: 57.00%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 26.13%
# Precision@3: 26.13%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 16.83%
# Precision@5: 16.83%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 8.96%
# Precision@10: 8.96%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 57.00%
# Recall@1: 57.00%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 78.38%
# Recall@3: 78.38%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 84.15%
# Recall@5: 84.15%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 89.56%
# Recall@10: 89.56%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.6876
# MRR@10: 0.6876
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.7385
# NDCG@10: 0.7385
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.6915
# MAP@100: 0.6915

# %% [markdown]
# ## 4.3 Run Evals

# %% [markdown]
# Run the Eval pipeline.

# %%
import pandas as pd

evaluate_st(val_dataset, model_id, "mxbai")
evaluate_st(val_dataset, finetuned_model_id, "finetuned_mxbai")

df_st_bge = pd.read_csv(
    "results/Information-Retrieval_evaluation_mxbai_results.csv"
)
df_st_finetuned = pd.read_csv(
    "results/Information-Retrieval_evaluation_finetuned_mxbai_results.csv"
)

df_st_bge["model"] = "mxbai"
df_st_finetuned["model"] = "finetuned_mxbai"
df_st_all = pd.concat([df_st_bge, df_st_finetuned])
df_st_all = df_st_all.set_index("model")
df_st_all
# Out:
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: mps
# Use pytorch device_name: mps
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: mixedbread-ai/mxbai-embed-xsmall-v1
# Load pretrained SentenceTransformer: mixedbread-ai/mxbai-embed-xsmall-v1
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the mxbai dataset:
# Information Retrieval Evaluation of the model on the mxbai dataset:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 814
# Queries: 814
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 407
#
# Corpus: 407
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cosine
# Score-Function: cosine
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 50.12%
# Accuracy@1: 50.12%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 72.48%
# Accuracy@3: 72.48%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 79.12%
# Accuracy@5: 79.12%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 85.75%
# Accuracy@10: 85.75%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 50.12%
# Precision@1: 50.12%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 24.16%
# Precision@3: 24.16%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 15.82%
# Precision@5: 15.82%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 8.57%
# Precision@10: 8.57%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 50.12%
# Recall@1: 50.12%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 72.48%
# Recall@3: 72.48%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 79.12%
# Recall@5: 79.12%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 85.75%
# Recall@10: 85.75%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.6267
# MRR@10: 0.6267
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.6829
# NDCG@10: 0.6829
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.6320
# MAP@100: 0.6320
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: mps
# Use pytorch device_name: mps
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: fine-tuned-mxbai-embed-xsmall-v1
# Load pretrained SentenceTransformer: fine-tuned-mxbai-embed-xsmall-v1
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the finetuned_mxbai dataset:
# Information Retrieval Evaluation of the model on the finetuned_mxbai dataset:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 814
# Queries: 814
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 407
#
# Corpus: 407
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cosine
# Score-Function: cosine
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 57.25%
# Accuracy@1: 57.25%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 78.26%
# Accuracy@3: 78.26%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 84.28%
# Accuracy@5: 84.28%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 89.56%
# Accuracy@10: 89.56%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 57.25%
# Precision@1: 57.25%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 26.09%
# Precision@3: 26.09%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 16.86%
# Precision@5: 16.86%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 8.96%
# Precision@10: 8.96%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 57.25%
# Recall@1: 57.25%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 78.26%
# Recall@3: 78.26%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 84.28%
# Recall@5: 84.28%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 89.56%
# Recall@10: 89.56%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.6881
# MRR@10: 0.6881
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.7388
# NDCG@10: 0.7388
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.6921
# MAP@100: 0.6921
#                  epoch  steps  cosine-Accuracy@1  cosine-Accuracy@3  \
# model
# mxbai               -1     -1           0.501229           0.724816
# finetuned_mxbai     -1     -1           0.572482           0.782555
#
#                  cosine-Accuracy@5  cosine-Accuracy@10  cosine-Precision@1  \
# model
# mxbai                     0.791155            0.857494            0.501229
# finetuned_mxbai           0.842752            0.895577            0.572482
#
#                  cosine-Recall@1  cosine-Precision@3  cosine-Recall@3  \
# model
# mxbai                   0.501229            0.241605         0.724816
# finetuned_mxbai         0.572482            0.260852         0.782555
#
#                  cosine-Precision@5  cosine-Recall@5  cosine-Precision@10  \
# model
# mxbai                      0.158231         0.791155             0.085749
# finetuned_mxbai            0.168550         0.842752             0.089558
#
#                  cosine-Recall@10  cosine-MRR@10  cosine-NDCG@10  \
# model
# mxbai                    0.857494       0.626660        0.682940
# finetuned_mxbai          0.895577       0.688057        0.738781
#
#                  cosine-MAP@100
# model
# mxbai                  0.632034
# finetuned_mxbai        0.692054

# %% [markdown]
# # 5. Finetune a proprietary IBM Slate embedding model using SentenceTransformers

# %% [markdown]
# ## 5.1 Define location of the model artifacts

# %% [markdown]
# Here we are refering to the local folder which contains all the model artifacts for the `slate-30m-english-rtrvr` embedding model

# %%
model_id = "slate-30m-english-rtrvr"
finetuned_model_id = "fine-tuned-slate-30m-english-rtrvr"

# %% [markdown]
# ## 5.2 Run the fine tuning process

# %% [markdown]
# Exactly same process as before

# %%
from llama_index.finetuning import SentenceTransformersFinetuneEngine
finetune_engine = SentenceTransformersFinetuneEngine(
    train_dataset,
    model_id=model_id,
    model_output_path=finetuned_model_id,
    val_dataset=val_dataset,
    epochs=5,
    use_all_docs=True
)
finetune_engine.finetune()
# Out:
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: mps
# Use pytorch device_name: mps
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: slate-30m-english-rtrvr
# Load pretrained SentenceTransformer: slate-30m-english-rtrvr
# Computing widget examples:   0%|          | 0/1 [00:00<?, ?example/s]
#     <div>
#
#       <progress value='345' max='345' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [345/345 01:23, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Cosine Accuracy@1</th>
#       <th>Cosine Accuracy@3</th>
#       <th>Cosine Accuracy@5</th>
#       <th>Cosine Accuracy@10</th>
#       <th>Cosine Precision@1</th>
#       <th>Cosine Precision@3</th>
#       <th>Cosine Precision@5</th>
#       <th>Cosine Precision@10</th>
#       <th>Cosine Recall@1</th>
#       <th>Cosine Recall@3</th>
#       <th>Cosine Recall@5</th>
#       <th>Cosine Recall@10</th>
#       <th>Cosine Ndcg@10</th>
#       <th>Cosine Mrr@10</th>
#       <th>Cosine Map@100</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.485258</td>
#       <td>0.675676</td>
#       <td>0.748157</td>
#       <td>0.819410</td>
#       <td>0.485258</td>
#       <td>0.225225</td>
#       <td>0.149631</td>
#       <td>0.081941</td>
#       <td>0.485258</td>
#       <td>0.675676</td>
#       <td>0.748157</td>
#       <td>0.819410</td>
#       <td>0.649847</td>
#       <td>0.595666</td>
#       <td>0.602681</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.486486</td>
#       <td>0.686732</td>
#       <td>0.761671</td>
#       <td>0.842752</td>
#       <td>0.486486</td>
#       <td>0.228911</td>
#       <td>0.152334</td>
#       <td>0.084275</td>
#       <td>0.486486</td>
#       <td>0.686732</td>
#       <td>0.761671</td>
#       <td>0.842752</td>
#       <td>0.661518</td>
#       <td>0.603693</td>
#       <td>0.609550</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.498771</td>
#       <td>0.697789</td>
#       <td>0.767813</td>
#       <td>0.855037</td>
#       <td>0.498771</td>
#       <td>0.232596</td>
#       <td>0.153563</td>
#       <td>0.085504</td>
#       <td>0.498771</td>
#       <td>0.697789</td>
#       <td>0.767813</td>
#       <td>0.855037</td>
#       <td>0.672603</td>
#       <td>0.614581</td>
#       <td>0.619844</td>
#     </tr>
#     <tr>
#       <td>138</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.502457</td>
#       <td>0.697789</td>
#       <td>0.769042</td>
#       <td>0.852580</td>
#       <td>0.502457</td>
#       <td>0.232596</td>
#       <td>0.153808</td>
#       <td>0.085258</td>
#       <td>0.502457</td>
#       <td>0.697789</td>
#       <td>0.769042</td>
#       <td>0.852580</td>
#       <td>0.673792</td>
#       <td>0.616822</td>
#       <td>0.622418</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.500000</td>
#       <td>0.701474</td>
#       <td>0.770270</td>
#       <td>0.850123</td>
#       <td>0.500000</td>
#       <td>0.233825</td>
#       <td>0.154054</td>
#       <td>0.085012</td>
#       <td>0.500000</td>
#       <td>0.701474</td>
#       <td>0.770270</td>
#       <td>0.850123</td>
#       <td>0.672805</td>
#       <td>0.616119</td>
#       <td>0.621955</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.502457</td>
#       <td>0.707617</td>
#       <td>0.775184</td>
#       <td>0.855037</td>
#       <td>0.502457</td>
#       <td>0.235872</td>
#       <td>0.155037</td>
#       <td>0.085504</td>
#       <td>0.502457</td>
#       <td>0.707617</td>
#       <td>0.775184</td>
#       <td>0.855037</td>
#       <td>0.675904</td>
#       <td>0.618734</td>
#       <td>0.624165</td>
#     </tr>
#     <tr>
#       <td>207</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.502457</td>
#       <td>0.706388</td>
#       <td>0.776413</td>
#       <td>0.855037</td>
#       <td>0.502457</td>
#       <td>0.235463</td>
#       <td>0.155283</td>
#       <td>0.085504</td>
#       <td>0.502457</td>
#       <td>0.706388</td>
#       <td>0.776413</td>
#       <td>0.855037</td>
#       <td>0.676093</td>
#       <td>0.618945</td>
#       <td>0.624370</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.509828</td>
#       <td>0.710074</td>
#       <td>0.781327</td>
#       <td>0.858722</td>
#       <td>0.509828</td>
#       <td>0.236691</td>
#       <td>0.156265</td>
#       <td>0.085872</td>
#       <td>0.509828</td>
#       <td>0.710074</td>
#       <td>0.781327</td>
#       <td>0.858722</td>
#       <td>0.681909</td>
#       <td>0.625368</td>
#       <td>0.630597</td>
#     </tr>
#     <tr>
#       <td>276</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.508600</td>
#       <td>0.706388</td>
#       <td>0.781327</td>
#       <td>0.858722</td>
#       <td>0.508600</td>
#       <td>0.235463</td>
#       <td>0.156265</td>
#       <td>0.085872</td>
#       <td>0.508600</td>
#       <td>0.706388</td>
#       <td>0.781327</td>
#       <td>0.858722</td>
#       <td>0.681602</td>
#       <td>0.625003</td>
#       <td>0.630216</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.508600</td>
#       <td>0.706388</td>
#       <td>0.781327</td>
#       <td>0.857494</td>
#       <td>0.508600</td>
#       <td>0.235463</td>
#       <td>0.156265</td>
#       <td>0.085749</td>
#       <td>0.508600</td>
#       <td>0.706388</td>
#       <td>0.781327</td>
#       <td>0.857494</td>
#       <td>0.681541</td>
#       <td>0.625252</td>
#       <td>0.630604</td>
#     </tr>
#     <tr>
#       <td>345</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.507371</td>
#       <td>0.706388</td>
#       <td>0.780098</td>
#       <td>0.857494</td>
#       <td>0.507371</td>
#       <td>0.235463</td>
#       <td>0.156020</td>
#       <td>0.085749</td>
#       <td>0.507371</td>
#       <td>0.706388</td>
#       <td>0.780098</td>
#       <td>0.857494</td>
#       <td>0.680738</td>
#       <td>0.624236</td>
#       <td>0.629601</td>
#     </tr>
#   </tbody>
# </table><p>
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 0.7246376811594203 after 50 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 0.7246376811594203 after 50 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 814
# Queries: 814
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 407
#
# Corpus: 407
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cosine
# Score-Function: cosine
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 48.53%
# Accuracy@1: 48.53%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 67.57%
# Accuracy@3: 67.57%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 74.82%
# Accuracy@5: 74.82%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 81.94%
# Accuracy@10: 81.94%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 48.53%
# Precision@1: 48.53%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 22.52%
# Precision@3: 22.52%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 14.96%
# Precision@5: 14.96%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 8.19%
# Precision@10: 8.19%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 48.53%
# Recall@1: 48.53%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 67.57%
# Recall@3: 67.57%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 74.82%
# Recall@5: 74.82%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 81.94%
# Recall@10: 81.94%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.5957
# MRR@10: 0.5957
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.6498
# NDCG@10: 0.6498
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.6027
# MAP@100: 0.6027
# INFO:sentence_transformers.SentenceTransformer:Save model to fine-tuned-slate-30m-english-rtrvr
# Save model to fine-tuned-slate-30m-english-rtrvr
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 1.0 after 69 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 1.0 after 69 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 814
# Queries: 814
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 407
#
# Corpus: 407
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cosine
# Score-Function: cosine
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 48.65%
# Accuracy@1: 48.65%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 68.67%
# Accuracy@3: 68.67%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 76.17%
# Accuracy@5: 76.17%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 84.28%
# Accuracy@10: 84.28%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 48.65%
# Precision@1: 48.65%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 22.89%
# Precision@3: 22.89%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 15.23%
# Precision@5: 15.23%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 8.43%
# Precision@10: 8.43%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 48.65%
# Recall@1: 48.65%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 68.67%
# Recall@3: 68.67%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 76.17%
# Recall@5: 76.17%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 84.28%
# Recall@10: 84.28%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.6037
# MRR@10: 0.6037
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.6615
# NDCG@10: 0.6615
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.6095
# MAP@100: 0.6095
# INFO:sentence_transformers.SentenceTransformer:Save model to fine-tuned-slate-30m-english-rtrvr
# Save model to fine-tuned-slate-30m-english-rtrvr
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 1.4492753623188406 after 100 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 1.4492753623188406 after 100 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 814
# Queries: 814
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 407
#
# Corpus: 407
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cosine
# Score-Function: cosine
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 49.88%
# Accuracy@1: 49.88%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 69.78%
# Accuracy@3: 69.78%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 76.78%
# Accuracy@5: 76.78%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 85.50%
# Accuracy@10: 85.50%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 49.88%
# Precision@1: 49.88%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 23.26%
# Precision@3: 23.26%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 15.36%
# Precision@5: 15.36%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 8.55%
# Precision@10: 8.55%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 49.88%
# Recall@1: 49.88%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 69.78%
# Recall@3: 69.78%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 76.78%
# Recall@5: 76.78%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 85.50%
# Recall@10: 85.50%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.6146
# MRR@10: 0.6146
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.6726
# NDCG@10: 0.6726
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.6198
# MAP@100: 0.6198
# INFO:sentence_transformers.SentenceTransformer:Save model to fine-tuned-slate-30m-english-rtrvr
# Save model to fine-tuned-slate-30m-english-rtrvr
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 2.0 after 138 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 2.0 after 138 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 814
# Queries: 814
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 407
#
# Corpus: 407
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cosine
# Score-Function: cosine
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 50.25%
# Accuracy@1: 50.25%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 69.78%
# Accuracy@3: 69.78%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 76.90%
# Accuracy@5: 76.90%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 85.26%
# Accuracy@10: 85.26%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 50.25%
# Precision@1: 50.25%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 23.26%
# Precision@3: 23.26%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 15.38%
# Precision@5: 15.38%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 8.53%
# Precision@10: 8.53%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 50.25%
# Recall@1: 50.25%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 69.78%
# Recall@3: 69.78%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 76.90%
# Recall@5: 76.90%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 85.26%
# Recall@10: 85.26%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.6168
# MRR@10: 0.6168
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.6738
# NDCG@10: 0.6738
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.6224
# MAP@100: 0.6224
# INFO:sentence_transformers.SentenceTransformer:Save model to fine-tuned-slate-30m-english-rtrvr
# Save model to fine-tuned-slate-30m-english-rtrvr
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 2.1739130434782608 after 150 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 2.1739130434782608 after 150 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 814
# Queries: 814
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 407
#
# Corpus: 407
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cosine
# Score-Function: cosine
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 50.00%
# Accuracy@1: 50.00%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 70.15%
# Accuracy@3: 70.15%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 77.03%
# Accuracy@5: 77.03%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 85.01%
# Accuracy@10: 85.01%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 50.00%
# Precision@1: 50.00%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 23.38%
# Precision@3: 23.38%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 15.41%
# Precision@5: 15.41%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 8.50%
# Precision@10: 8.50%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 50.00%
# Recall@1: 50.00%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 70.15%
# Recall@3: 70.15%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 77.03%
# Recall@5: 77.03%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 85.01%
# Recall@10: 85.01%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.6161
# MRR@10: 0.6161
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.6728
# NDCG@10: 0.6728
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.6220
# MAP@100: 0.6220
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 2.898550724637681 after 200 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 2.898550724637681 after 200 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 814
# Queries: 814
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 407
#
# Corpus: 407
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cosine
# Score-Function: cosine
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 50.25%
# Accuracy@1: 50.25%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 70.76%
# Accuracy@3: 70.76%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 77.52%
# Accuracy@5: 77.52%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 85.50%
# Accuracy@10: 85.50%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 50.25%
# Precision@1: 50.25%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 23.59%
# Precision@3: 23.59%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 15.50%
# Precision@5: 15.50%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 8.55%
# Precision@10: 8.55%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 50.25%
# Recall@1: 50.25%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 70.76%
# Recall@3: 70.76%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 77.52%
# Recall@5: 77.52%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 85.50%
# Recall@10: 85.50%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.6187
# MRR@10: 0.6187
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.6759
# NDCG@10: 0.6759
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.6242
# MAP@100: 0.6242
# INFO:sentence_transformers.SentenceTransformer:Save model to fine-tuned-slate-30m-english-rtrvr
# Save model to fine-tuned-slate-30m-english-rtrvr
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 3.0 after 207 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 3.0 after 207 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 814
# Queries: 814
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 407
#
# Corpus: 407
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cosine
# Score-Function: cosine
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 50.25%
# Accuracy@1: 50.25%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 70.64%
# Accuracy@3: 70.64%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 77.64%
# Accuracy@5: 77.64%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 85.50%
# Accuracy@10: 85.50%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 50.25%
# Precision@1: 50.25%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 23.55%
# Precision@3: 23.55%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 15.53%
# Precision@5: 15.53%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 8.55%
# Precision@10: 8.55%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 50.25%
# Recall@1: 50.25%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 70.64%
# Recall@3: 70.64%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 77.64%
# Recall@5: 77.64%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 85.50%
# Recall@10: 85.50%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.6189
# MRR@10: 0.6189
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.6761
# NDCG@10: 0.6761
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.6244
# MAP@100: 0.6244
# INFO:sentence_transformers.SentenceTransformer:Save model to fine-tuned-slate-30m-english-rtrvr
# Save model to fine-tuned-slate-30m-english-rtrvr
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 3.6231884057971016 after 250 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 3.6231884057971016 after 250 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 814
# Queries: 814
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 407
#
# Corpus: 407
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cosine
# Score-Function: cosine
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 50.98%
# Accuracy@1: 50.98%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 71.01%
# Accuracy@3: 71.01%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 78.13%
# Accuracy@5: 78.13%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 85.87%
# Accuracy@10: 85.87%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 50.98%
# Precision@1: 50.98%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 23.67%
# Precision@3: 23.67%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 15.63%
# Precision@5: 15.63%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 8.59%
# Precision@10: 8.59%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 50.98%
# Recall@1: 50.98%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 71.01%
# Recall@3: 71.01%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 78.13%
# Recall@5: 78.13%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 85.87%
# Recall@10: 85.87%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.6254
# MRR@10: 0.6254
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.6819
# NDCG@10: 0.6819
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.6306
# MAP@100: 0.6306
# INFO:sentence_transformers.SentenceTransformer:Save model to fine-tuned-slate-30m-english-rtrvr
# Save model to fine-tuned-slate-30m-english-rtrvr
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 4.0 after 276 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 4.0 after 276 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 814
# Queries: 814
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 407
#
# Corpus: 407
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cosine
# Score-Function: cosine
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 50.86%
# Accuracy@1: 50.86%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 70.64%
# Accuracy@3: 70.64%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 78.13%
# Accuracy@5: 78.13%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 85.87%
# Accuracy@10: 85.87%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 50.86%
# Precision@1: 50.86%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 23.55%
# Precision@3: 23.55%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 15.63%
# Precision@5: 15.63%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 8.59%
# Precision@10: 8.59%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 50.86%
# Recall@1: 50.86%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 70.64%
# Recall@3: 70.64%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 78.13%
# Recall@5: 78.13%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 85.87%
# Recall@10: 85.87%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.6250
# MRR@10: 0.6250
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.6816
# NDCG@10: 0.6816
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.6302
# MAP@100: 0.6302
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 4.3478260869565215 after 300 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 4.3478260869565215 after 300 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 814
# Queries: 814
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 407
#
# Corpus: 407
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cosine
# Score-Function: cosine
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 50.86%
# Accuracy@1: 50.86%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 70.64%
# Accuracy@3: 70.64%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 78.13%
# Accuracy@5: 78.13%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 85.75%
# Accuracy@10: 85.75%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 50.86%
# Precision@1: 50.86%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 23.55%
# Precision@3: 23.55%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 15.63%
# Precision@5: 15.63%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 8.57%
# Precision@10: 8.57%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 50.86%
# Recall@1: 50.86%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 70.64%
# Recall@3: 70.64%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 78.13%
# Recall@5: 78.13%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 85.75%
# Recall@10: 85.75%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.6253
# MRR@10: 0.6253
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.6815
# NDCG@10: 0.6815
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.6306
# MAP@100: 0.6306
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the  dataset in epoch 5.0 after 345 steps:
# Information Retrieval Evaluation of the model on the  dataset in epoch 5.0 after 345 steps:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 814
# Queries: 814
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 407
#
# Corpus: 407
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cosine
# Score-Function: cosine
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 50.74%
# Accuracy@1: 50.74%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 70.64%
# Accuracy@3: 70.64%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 78.01%
# Accuracy@5: 78.01%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 85.75%
# Accuracy@10: 85.75%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 50.74%
# Precision@1: 50.74%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 23.55%
# Precision@3: 23.55%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 15.60%
# Precision@5: 15.60%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 8.57%
# Precision@10: 8.57%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 50.74%
# Recall@1: 50.74%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 70.64%
# Recall@3: 70.64%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 78.01%
# Recall@5: 78.01%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 85.75%
# Recall@10: 85.75%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.6242
# MRR@10: 0.6242
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.6807
# NDCG@10: 0.6807
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.6296
# MAP@100: 0.6296

# %% [markdown]
# ## 5.3 Run Eval

# %% [markdown]
# Run the same Eval pipeline and compare

# %%
evaluate_st(val_dataset, model_id, "slate")
evaluate_st(val_dataset, finetuned_model_id, "finetuned_slate")

df_st_bge = pd.read_csv(
    "results/Information-Retrieval_evaluation_slate_results.csv"
)
df_st_finetuned = pd.read_csv(
    "results/Information-Retrieval_evaluation_finetuned_slate_results.csv"
)

df_st_bge["model"] = "slate"
df_st_finetuned["model"] = "finetuned_slate"
df_st_all = pd.concat([df_st_bge, df_st_finetuned])
df_st_all = df_st_all.set_index("model")
df_st_all
# Out:
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: mps
# Use pytorch device_name: mps
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: slate-30m-english-rtrvr
# Load pretrained SentenceTransformer: slate-30m-english-rtrvr
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the slate dataset:
# Information Retrieval Evaluation of the model on the slate dataset:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 814
# Queries: 814
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 407
#
# Corpus: 407
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cosine
# Score-Function: cosine
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 40.66%
# Accuracy@1: 40.66%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 60.57%
# Accuracy@3: 60.57%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 66.58%
# Accuracy@5: 66.58%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 74.82%
# Accuracy@10: 74.82%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 40.66%
# Precision@1: 40.66%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 20.19%
# Precision@3: 20.19%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 13.32%
# Precision@5: 13.32%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 7.48%
# Precision@10: 7.48%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 40.66%
# Recall@1: 40.66%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 60.57%
# Recall@3: 60.57%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 66.58%
# Recall@5: 66.58%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 74.82%
# Recall@10: 74.82%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.5184
# MRR@10: 0.5184
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.5738
# NDCG@10: 0.5738
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.5274
# MAP@100: 0.5274
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: mps
# Use pytorch device_name: mps
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: fine-tuned-slate-30m-english-rtrvr
# Load pretrained SentenceTransformer: fine-tuned-slate-30m-english-rtrvr
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Information Retrieval Evaluation of the model on the finetuned_slate dataset:
# Information Retrieval Evaluation of the model on the finetuned_slate dataset:
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Queries: 814
# Queries: 814
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Corpus: 407
#
# Corpus: 407
#
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Score-Function: cosine
# Score-Function: cosine
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@1: 50.98%
# Accuracy@1: 50.98%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@3: 71.01%
# Accuracy@3: 71.01%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@5: 78.13%
# Accuracy@5: 78.13%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Accuracy@10: 85.87%
# Accuracy@10: 85.87%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@1: 50.98%
# Precision@1: 50.98%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@3: 23.67%
# Precision@3: 23.67%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@5: 15.63%
# Precision@5: 15.63%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Precision@10: 8.59%
# Precision@10: 8.59%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@1: 50.98%
# Recall@1: 50.98%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@3: 71.01%
# Recall@3: 71.01%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@5: 78.13%
# Recall@5: 78.13%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:Recall@10: 85.87%
# Recall@10: 85.87%
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MRR@10: 0.6254
# MRR@10: 0.6254
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:NDCG@10: 0.6819
# NDCG@10: 0.6819
# INFO:sentence_transformers.evaluation.InformationRetrievalEvaluator:MAP@100: 0.6306
# MAP@100: 0.6306
#                  epoch  steps  cosine-Accuracy@1  cosine-Accuracy@3  \
# model
# slate               -1     -1           0.406634           0.605651
# finetuned_slate     -1     -1           0.509828           0.710074
#
#                  cosine-Accuracy@5  cosine-Accuracy@10  cosine-Precision@1  \
# model
# slate                     0.665848            0.748157            0.406634
# finetuned_slate           0.781327            0.858722            0.509828
#
#                  cosine-Recall@1  cosine-Precision@3  cosine-Recall@3  \
# model
# slate                   0.406634            0.201884         0.605651
# finetuned_slate         0.509828            0.236691         0.710074
#
#                  cosine-Precision@5  cosine-Recall@5  cosine-Precision@10  \
# model
# slate                      0.133170         0.665848             0.074816
# finetuned_slate            0.156265         0.781327             0.085872
#
#                  cosine-Recall@10  cosine-MRR@10  cosine-NDCG@10  \
# model
# slate                    0.748157       0.518350        0.573785
# finetuned_slate          0.858722       0.625368        0.681909
#
#                  cosine-MAP@100
# model
# slate                  0.527359
# finetuned_slate        0.630597
